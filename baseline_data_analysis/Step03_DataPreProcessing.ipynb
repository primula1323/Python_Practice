# %%
import numpy as np, pandas as pd

# %%
df = pd.read_csv('forked_Bigdata_Analyst_Cert/part4/ch7/air_quality.csv')

# %% [markdown]
# ## Data type transform

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp         int64
# Month        int64
# Day          int64
# dtype: object

# %%
dfk = df.copy()
dfk['months'] = dfk['Month'].astype('int')
dfk
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day month  months
# 0     41.0    190.0   7.4    67      5    1     5       5
# 1     36.0    118.0   8.0    72      5    2     5       5
# 2     12.0    149.0  12.6    74      5    3     5       5
# 3     18.0    313.0  11.5    62      5    4     5       5
# 4      NaN      NaN  14.3    56      5    5     5       5
# ..     ...      ...   ...   ...    ...  ...   ...     ...
# 148   30.0    193.0   6.9    70      9   26     9       9
# 149    NaN    145.0  13.2    77      9   27     9       9
# 150   14.0    191.0  14.3    75      9   28     9       9
# 151   18.0    131.0   8.0    76      9   29     9       9
# 152   20.0    223.0  11.5    68      9   30     9       9
#
# [153 rows x 8 columns]

# %% [markdown]
# ### check duplicated rows

# %%
df.duplicated().sum()
df.drop_duplicates()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day month  months
# 0     41.0    190.0   7.4    67      5    1     5       5
# 1     36.0    118.0   8.0    72      5    2     5       5
# 2     12.0    149.0  12.6    74      5    3     5       5
# 3     18.0    313.0  11.5    62      5    4     5       5
# 4      NaN      NaN  14.3    56      5    5     5       5
# ..     ...      ...   ...   ...    ...  ...   ...     ...
# 148   30.0    193.0   6.9    70      9   26     9       9
# 149    NaN    145.0  13.2    77      9   27     9       9
# 150   14.0    191.0  14.3    75      9   28     9       9
# 151   18.0    131.0   8.0    76      9   29     9       9
# 152   20.0    223.0  11.5    68      9   30     9       9
#
# [153 rows x 8 columns]

# %% [markdown]
# ## Process Datetime Data

# %%
import datetime #cannot use in exam

# %%
help(pd.Series.dt)
# Out:
# Help on class CombinedDatetimelikeProperties in module pandas.core.indexes.accessors:
#
# class CombinedDatetimelikeProperties(DatetimeProperties, TimedeltaProperties, PeriodProperties)
#  |  CombinedDatetimelikeProperties(data: 'Series')
#  |
#  |  Method resolution order:
#  |      CombinedDatetimelikeProperties
#  |      DatetimeProperties
#  |      TimedeltaProperties
#  |      PeriodProperties
#  |      Properties
#  |      pandas.core.accessor.PandasDelegate
#  |      pandas.core.base.PandasObject
#  |      pandas.core.accessor.DirNamesMixin
#  |      pandas.core.base.NoNewAttributesMixin
#  |      builtins.object
#  |
#  |  Static methods defined here:
#  |
#  |  __new__(cls, data: 'Series')
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
# ...

# %% [markdown]
# ## Processing NAs

# %% [markdown]
# ### df.dropna() : drop NAs

# %%
#axis = 0 or 'index' vs. 1 or 'columns'
df.dropna(axis = 'columns'), df.dropna(axis = 'columns').shape
# Out:
# (     Wind  Temp  Month  Day
#  0     7.4    67      5    1
#  1     8.0    72      5    2
#  2    12.6    74      5    3
#  3    11.5    62      5    4
#  4    14.3    56      5    5
#  ..    ...   ...    ...  ...
#  148   6.9    70      9   26
#  149  13.2    77      9   27
#  150  14.3    75      9   28
#  151   8.0    76      9   29
#  152  11.5    68      9   30
#
#  [153 rows x 4 columns],
#  (153, 4))

# %%
#subset = [] option to ignore other columns
df.dropna(subset = ['Ozone'], how = 'any'), df.dropna(subset = ['Ozone'], how = 'any').shape
# Out:
# (     Ozone  Solar.R  Wind  Temp  Month  Day
#  0     41.0    190.0   7.4    67      5    1
#  1     36.0    118.0   8.0    72      5    2
#  2     12.0    149.0  12.6    74      5    3
#  3     18.0    313.0  11.5    62      5    4
#  5     28.0      NaN  14.9    66      5    6
#  ..     ...      ...   ...   ...    ...  ...
#  147   14.0     20.0  16.6    63      9   25
#  148   30.0    193.0   6.9    70      9   26
#  150   14.0    191.0  14.3    75      9   28
#  151   18.0    131.0   8.0    76      9   29
#  152   20.0    223.0  11.5    68      9   30
#
#  [116 rows x 6 columns],
#  (116, 6))

# %% [markdown]
# ### df.fillna() : replace NAs with other values

# %%
df.fillna(df.mean())
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day
# 0    41.00000  190.000000   7.4    67      5    1
# 1    36.00000  118.000000   8.0    72      5    2
# 2    12.00000  149.000000  12.6    74      5    3
# 3    18.00000  313.000000  11.5    62      5    4
# 4    42.12931  185.931507  14.3    56      5    5
# ..        ...         ...   ...   ...    ...  ...
# 148  30.00000  193.000000   6.9    70      9   26
# 149  42.12931  145.000000  13.2    77      9   27
# 150  14.00000  191.000000  14.3    75      9   28
# 151  18.00000  131.000000   8.0    76      9   29
# 152  20.00000  223.000000  11.5    68      9   30
#
# [153 rows x 6 columns]

# %%
df.fillna(df.mean()).isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
df.loc[]


#data slice 


df.iloc
# Out:
#   Cell In[4], line 1
#     df.loc[]
#            ^
# SyntaxError: invalid syntax

# %%
df.loc[:].idxmax() #idxmax(axis = 0) : 최댓값이 포함된 열/행

# %%
#data slicing by index

df.iloc[:int(len(df)*0.7)]
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 102    NaN    137.0  11.5    86      8   11
# 103   44.0    192.0  11.5    86      8   12
# 104   28.0    273.0  11.5    82      8   13
# 105   65.0    157.0   9.7    80      8   14
# 106    NaN     64.0  11.5    79      8   15
#
# [107 rows x 6 columns]

# %%
from sklearn.metrics import root_mean_squared_error
# Out:
# 153

# %%
df.corr(numeric_only=True)

# %% [markdown]
# ## 날짜
