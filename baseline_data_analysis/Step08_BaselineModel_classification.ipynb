# %%
import pandas as pd, numpy as np

# %%
train = pd.read_csv('forked_Bigdata_Analyst_Cert/part2/ch5/train.csv')
test = pd.read_csv('forked_Bigdata_Analyst_Cert/part2/ch5/test.csv')

# %%
train.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Delay_from_due_date       10000 non-null  float64
#  1   Num_of_Delayed_Payment    10000 non-null  float64
#  2   Num_Credit_Inquiries      10000 non-null  float64
#  3   Credit_Utilization_Ratio  10000 non-null  float64
#  4   Credit_History_Age        10000 non-null  float64
#  5   Payment_of_Min_Amount     10000 non-null  object
#  6   Amount_invested_monthly   10000 non-null  float64
#  7   Monthly_Balance           10000 non-null  float64
#  8   Credit_Score              10000 non-null  int64
#  9   Credit_Mix                10000 non-null  object
#  10  Payment_Behaviour         10000 non-null  object
#  11  Age                       10000 non-null  float64
#  12  Annual_Income             10000 non-null  float64
# ...

# %%
train.nunique()
# Out:
# Delay_from_due_date            68
# Num_of_Delayed_Payment         29
# Num_Credit_Inquiries           18
# Credit_Utilization_Ratio    10000
# Credit_History_Age            403
# Payment_of_Min_Amount           3
# Amount_invested_monthly      9907
# Monthly_Balance              9989
# Credit_Score                    3
# Credit_Mix                      3
# Payment_Behaviour               6
# Age                            43
# Annual_Income                7143
# Num_Bank_Accounts              11
# Num_Credit_Card                12
# Interest_Rate                  34
# Num_of_Loan                    10
# Monthly_Inhand_Salary        7148
# Changed_Credit_Limit         2234
# Outstanding_Debt             7049
# Total_EMI_per_month          6342
# dtype: int64

# %%
train.head()
# Out:
#    Delay_from_due_date  Num_of_Delayed_Payment  Num_Credit_Inquiries  \
# 0                 56.0                    16.0                  11.0
# 1                 49.0                    23.0                  12.0
# 2                 34.0                    20.0                   6.0
# 3                 21.0                    13.0                   8.0
# 4                 19.0                    13.0                   6.0
#
#    Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 0                 35.598217               120.0                   Yes
# 1                 25.553106               120.0                   Yes
# 2                 40.039954               174.0                   Yes
# 3                 25.711678               143.0                    NM
# 4                 39.140463               138.0                   Yes
#
#    Amount_invested_monthly  Monthly_Balance  Credit_Score Credit_Mix  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.impute import SimpleImputer, KNNImputer

from sklearn.model_selection import train_test_split

# %%
target_cols = ['Credit_Score']
learning_cols = list(train.columns)
learning_cols.remove('Credit_Score')
discr_cols = list(train.columns[train.dtypes == object])
conti_cols = [col for col in learning_cols if col not in discrete_cols]

# %%
oe = OrdinalEncoder(handle_unknown = 'use_encoded_value', unknown_value = -1)
oe.fit(train[discr_cols])

ss = StandardScaler()
ss.fit(train[conti_cols])

le = LabelEncoder()
le.fit(train[target_cols[0]])
# Out:
# LabelEncoder()

# %%
train[discr_cols] = oe.fit_transform(train[discr_cols])
test[discr_cols] = oe.fit_transform(test[discr_cols])

train[conti_cols] = ss.fit_transform(train[conti_cols])
test[conti_cols] = ss.fit_transform(test[conti_cols])

train[target_cols[0]] = le.fit_transform(train[target_cols[0]])

# %%
X_tr, X_va, y_tr, y_va = train_test_split(train[learning_cols], train[target_cols[0]], test_size = 0.2)

# %%
from sklearn.ensemble import RandomForestClassifier as rfc
from xgboost import XGBClassifier as xgbc
from lightgbm import LGBMClassifier as lgbmc

# %%
rfm1 = rfc(class_weight = 'balanced')
rfm1.fit(X_tr, y_tr)
# Out:
# RandomForestClassifier()

# %%
xgbm1 = xgbc()
xgbm1.fit(X_tr, y_tr)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
lgbm1 = lgbmc(verbose = -1)
lgbm1.fit(X_tr, y_tr)
# Out:
# LGBMClassifier(verbose=-1)

# %%
from sklearn.metrics import f1_score

# %%
pred1 = rfm1.predict(X_va)
pred2 = lgbm1.predict(X_va)
pred3 = xgbm1.predict(X_va)
f1_score(y_va, pred1, average = 'macro'), f1_score(y_va, pred2, average = 'macro'), f1_score(y_va, pred3, average = 'macro')
# Out:
# (0.7017123467068712, 0.6955580132531672, 0.6933813162238645)

# %%
from sklearn.metrics import root_mean_squared_log_error

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.model_selection import train_test_split

# %%
learning_cols = ['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
target_cols = ['Item_Outlet_Sales']

obj_cols = list(df_train.columns[df_train.dtypes == object])
obj_cols.remove('Item_Identifier')

real_cols = [col for col in learning_cols if col not in obj_cols]

# %%
encoder = OrdinalEncoder()
encoder.fit(df_train[obj_cols])
df_train[obj_cols] = encoder.fit_transform(df_train[obj_cols])
df_test[obj_cols] = encoder.fit_transform(df_test[obj_cols])

le = LabelEncoder()
le.fit(df_train[target_cols])
df_train[target_cols] = encoder.fit_transform(df_train[obj_cols])
df_test[target_cols] = encoder.fit_transform(df_test[obj_cols])

scaler = StandardScaler()
scaler.fit(df_train[real_cols])
df_train[real_cols] = scaler.fit_transform(df_train[real_cols])
df_test[real_cols] = scaler.fit_transform(df_test[real_cols])

# %%
imputer_Outlet_Size = SimpleImputer(strategy = 'most_frequent')
imputer_Outlet_Size.fit(df_train[obj_cols])
df_train[obj_cols] = imputer_Outlet_Size.fit_transform(df_train[obj_cols])

imputer_Item_Weight = KNNImputer()
imputer_Item_Weight.fit(df_train[learning_cols])
df_train[learning_cols] = imputer_Item_Weight.fit_transform(df_train[learning_cols])
df_test[learning_cols] = imputer_Item_Weight.fit_transform(df_test[learning_cols])

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train[learning_cols], df_train[target_cols], test_size = 0.2, random_state = 42)

# %%
from sklearn.preprocessing import OrdinalEncoder
import numpy as np

# Example data
X_train = np.array([['A'], ['B'], ['C'], ['D']])
X_test = np.array([['A'], ['B'], ['F']])

# OrdinalEncoder
encoder = OrdinalEncoder()
encoder.fit(X_train)

# Transform X_test
encoder.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 13
#      10 encoder.fit(X_train)
#      12 # Transform X_test
# ---> 13 encoder.transform(X_test)
#
# File c:\Users\Na\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# ...
