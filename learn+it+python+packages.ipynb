# %%
import numpy as np, pandas as pd

# %% [markdown]
# ## numpy arrays

# %% [markdown]
# ## pandas

# %%
#df.sort_values(ascending = True, inplace = False)
#df.vaule_counts(ascending = True) : 빈도분석 결과
#df.unique()
